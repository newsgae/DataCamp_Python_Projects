# %%
#load required modules
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# handle time seies data
from datetime import date, datetime, timedelta

# %% [markdown]
# ## 1. biological data

# %%
# Querying DEOS - UD Farm
import os
os.chdir('D:\\3. WorkSpace\\Drone Project\\2020 CA alfalfa')
os.getcwd()

# Loading Excel
df = pd.read_excel(r'D:\3. WorkSpace\Drone Project\2020 CA alfalfa\2. Data\5. biological and python data\data-drone_aircraft_2020.xlsx',
                   sheet_name = 'Biological')
#df['date'] = pd.to_datetime(df['date']).dt.strftime("%Y%m%d")
df = df.set_index(['exp_unit'])
df
# Out:
#           reps   trtment  armyworm    ne    dat location       date
# exp_unit
# 1            1   Control       115   8.0  3 DAT   Harlan 2020-08-27
# 2            2   Control        56   1.0  3 DAT   Harlan 2020-08-27
# 3            3   Control        66   1.0  3 DAT   Harlan 2020-08-27
# 4            4   Control        49   1.0  3 DAT   Harlan 2020-08-27
# 5            1     Drone        11  23.0  3 DAT   Harlan 2020-08-27
# 6            2     Drone         4   4.0  3 DAT   Harlan 2020-08-27
# 7            3     Drone         6   1.0  3 DAT   Harlan 2020-08-27
# 8            4     Drone         9   1.0  3 DAT   Harlan 2020-08-27
# 9            1  Airplane         6  11.0  3 DAT   Harlan 2020-08-27
# 10           2  Airplane         8  17.0  3 DAT   Harlan 2020-08-27
# 11           3  Airplane         5   7.0  3 DAT   Harlan 2020-08-27
# 12           4  Airplane         7  10.0  3 DAT   Harlan 2020-08-27
# 13           1   Control        47   2.0  5 DAT   Harlan 2020-08-29
# ...

# %%
 df.iloc[48:52]['armyworm'].describe()
# df.iloc[52:57]['armyworm'].mean()
# df.iloc[52:57]['ne'].mean()
# Out:
# count      4.000000
# mean      67.500000
# std       28.769196
# min       48.000000
# 25%       51.000000
# 50%       56.000000
# 75%       72.500000
# max      110.000000
# Name: armyworm, dtype: float64

# %%
#  plot comparison data - summer worm control
harlan = df.iloc[0:24]
#harlan
payne = df.iloc[24:48]

#payne
# plot comparison data -  PEST 
fig, axes = plt.subplots(nrows=1,ncols=2,figsize = (12, 6))
sns.set(font_scale = 1.2)
sns.set_style("white")
## plot armyworm 10 GPA
g1=sns.boxplot(x = harlan['trtment'],y = harlan['armyworm'],hue = harlan['dat'],data = harlan,ax=axes[0],
            order=['Control','Drone','Airplane'],palette='Purples',
              showmeans=True,
              meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
# Add transparency to colors
for patch in g1.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor((r, g, b, .5))
# style   
g1.set_ylabel('Number of Lepidopteran Larvae per 10 Sweeps',fontsize=16,fontweight='bold')
g1.set_xlabel('')
labels=['Untreated\nControl','UAV\n(PV35)','Airplane\n(AT-502)']
g1.set_xticklabels(labels,fontsize=14,fontweight='bold')
g1.set_title('Field Site A (93.5 L/ha or 10 GPA)',fontweight='bold')

horiz_line_data = df.iloc[48:52]['armyworm'].mean()
g1.axhline(y=horiz_line_data,color='gray',linewidth=3, linestyle=':',label='0 DAT')
#g1.hlines(y=horiz_line_data, xmin=xlim[0], xmax=xlim[1], colors='gray', linestyles=':', label='0 DAY')
g1.legend(loc=1,fontsize = 12) 
######################################################################    
## plot armyworm 5 GPA
g2=sns.boxplot(x = payne['trtment'],y = payne['armyworm'],hue = payne['dat'],data = payne,ax=axes[1],
            order=['Control','Drone','Airplane'],palette='BuGn',
              showmeans=True,
              meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
# Add transparency to colors
for patch in g2.artists:
 r,g,b, a = patch.get_facecolor()
 patch.set_facecolor(( r, g, b,.5))
# style   
g2.set_ylabel('Number of Lepidopteran Larvae per 10 Sweeps',fontsize=16,fontweight='bold')
g2.set_xlabel('')
labels=['Untreated\nControl','UAV\n(PV35)','Airplane\n(AG-CAT D)']
g2.set_xticklabels(labels,fontsize=14,fontweight='bold')
g2.set_title('Field Site B (46.8 L/ha or 5 GPA)',fontweight='bold')
# g2.set_ylim(0,120)
# add mean at 0DAY
horiz_line_data = df.iloc[52:57]['armyworm'].mean()
g2.axhline(y=horiz_line_data,color='gray',linewidth=3, linestyle=':',label='0 DAT')
g2.legend(loc=1,fontsize = 12) 

# st=fig.suptitle("Larval pest control by application methods over time",fontsize=18,fontweight='bold')
# st.set_y(1.05)
fig.tight_layout()
fig.savefig('D:\\3. WorkSpace\\Drone Project\\2020 CA alfalfa\pestPMS.jpg',
            format='jpg', dpi=600)

# %% [markdown]
# ### For Rachael Magazine: Predator

# %%
#  plot comparison data - ne
harlan = df.iloc[0:24]
#harlan
payne = df.iloc[24:48]
# remove UTC 3-5 DAT data
harlan_sw=harlan[harlan['trtment']!= 'Control']
payne_sw=payne[payne['trtment']!= 'Control']

#payne
# plot comparison data -  PEST 
fig, axes = plt.subplots(nrows=1,ncols=2,figsize = (12, 6))
sns.set(font_scale = 1.2)
sns.set_style("white")
## plot armyworm 10 GPA
g1=sns.boxplot(x = harlan_sw['trtment'],y = harlan_sw['armyworm'],hue = harlan_sw['dat'],data = harlan_sw,
               ax=axes[0],
               order=['Drone','Airplane'],palette='Purples',
              showmeans=True,
              meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
# Add transparency to colors
for patch in g1.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor((r, g, b, .5))
# style   
g1.set_ylabel('Number of Summer Worms per 10 Sweeps',fontsize=16,fontweight='bold')
g1.set_xlabel('')
labels=['UAV','Airplane']
g1.set_xticklabels(labels,fontsize=14,fontweight='bold')
g1.set_title('Field Site #1 (10 GPA)',fontweight='bold')

horiz_line_data = df.iloc[48:52]['armyworm'].mean()
g1.axhline(y=horiz_line_data,color='gray',linewidth=3, linestyle=':',label='0 DAY')
#g1.hlines(y=horiz_line_data, xmin=xlim[0], xmax=xlim[1], colors='gray', linestyles=':', label='0 DAY')
g1.legend(loc=1,fontsize = 12) 
######################################################################    
## plot armyworm 5 GPA
g2=sns.boxplot(x = payne_sw['trtment'],y = payne_sw['armyworm'],hue = payne_sw['dat'],data = payne_sw,
               ax=axes[1],
            order=['Drone','Airplane'],palette='BuGn',
              showmeans=True,
              meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
# Add transparency to colors
for patch in g2.artists:
 r,g,b, a = patch.get_facecolor()
 patch.set_facecolor(( r, g, b,.5))
# style   
g2.set_ylabel('Number of Summer Worms per 10 Sweeps',fontsize=16,fontweight='bold')
g2.set_xlabel('')
labels=['UAV','Airplane']
g2.set_xticklabels(labels,fontsize=14,fontweight='bold')
g2.set_title('Field Site #2 (5 GPA)',fontweight='bold')
# g2.set_ylim(0,120)
# add mean at 0DAY
horiz_line_data = df.iloc[52:57]['armyworm'].mean()
g2.axhline(y=horiz_line_data,color='gray',linewidth=3, linestyle=':',label='0 DAY')
g2.legend(loc=1,fontsize = 12) 

# st=fig.suptitle("Larval pest control by application methods over time",fontsize=18,fontweight='bold')
# st.set_y(1.05)
fig.tight_layout()
fig.savefig('D:\\3. WorkSpace\\Drone Project\\2020 CA alfalfa\pestMAZ.jpg',
            format='jpg', dpi=600)

# %%
# plot comparison data - natural enemy
harlan_ne = df.iloc[0:24]
#harlan
payne_ne = df.iloc[24:48]
# # remove UTC 3-5 DAT data
# harlan_ne=harlan[harlan['trtment']!= 'Control']
# payne_ne=payne[payne['trtment']!= 'Control']
fig, axes = plt.subplots(nrows=1,ncols=2,figsize = (12, 6))
sns.set(font_scale = 1.2)
sns.set_style("white")
## plot armyworm 10 GPA
g1=sns.boxplot(x = harlan_ne['trtment'],y = harlan_ne['ne'],
               hue = harlan_ne['dat'],data = harlan_ne,ax=axes[0],
            order=['Control','Drone','Airplane'],palette='Purples',
            showmeans=True,width=0.6,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})

# Add transparency to colors
for patch in g1.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor((r, g, b, .5))
# style   
g1.set_ylabel('Number of Predators per 10 Sweeps',fontsize=16,fontweight='bold')
g1.legend(loc=2,fontsize = 12) 
g1.set_xlabel('')
labels=['Untreated\nControl','UAV\n(PV35)','Airplane\n(AT-502)']
g1.set_xticklabels(labels,fontsize=16,fontweight='bold')
g1.set_title('Field Site A (93.5 L/ha or 10 GPA)',fontweight='bold')
g1.set_ylim(0,30)

# add mean at 0DAY
horiz_line_data = df.iloc[48:52]['ne'].mean()
g1.axhline(y=horiz_line_data,color='gray',linewidth=3, linestyle=':',label='0 DAT')
#g1.hlines(y=horiz_line_data, xmin=xlim[0], xmax=xlim[1], colors='gray', linestyles=':', label='0 DAY')
g1.legend(loc=2,fontsize = 12) 

######################################################################    
## plot armyworm 5 GPA
g2=sns.boxplot(x = payne_ne['trtment'],y = payne_ne['ne'],
               hue = payne_ne['dat'],data = payne_ne,ax=axes[1],
            order=['Control','Drone','Airplane'],palette='BuGn',showmeans=True,width=0.6,
              meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
# Add transparency to colors
for patch in g2.artists:
 r,g,b, a = patch.get_facecolor()
 patch.set_facecolor(( r, g, b,.5))
# add mean at 0DAY
horiz_line_data = df.iloc[52:57]['ne'].mean()
g2.axhline(y=horiz_line_data,color='gray',linewidth=3, linestyle=':',label='0 DAT')
g2.legend(loc=2,fontsize = 12) 
# style   
g2.set_ylabel('Number of Predators per 10 Sweeps',fontsize=16,fontweight='bold')
g2.legend(loc=0,fontsize = 12) 
g2.set_xlabel('')
labels=['Untreated\nControl','UAV\n(PV35)','Airplane\n(AG-CAT D)']
g2.set_ylim(0,30)
g2.set_xticklabels(labels,fontsize=16,fontweight='bold')
g2.set_title('Field Site B (46.8 L/ha or 5 GPA)',fontweight='bold')

# # Add a table at the bottom of the axes
# the_table = plt.table(cellText=cell_text,
#                       rowLabels=rows,
#                       rowColours=colors,
#                       colLabels=columns,
#                       loc='bottom')
# st=fig.suptitle("Natural enemy population by application methods over time ",fontsize=18,fontweight='bold')
# st.set_y(1.05)
fig.tight_layout()
fig.savefig('D:\\3. WorkSpace\\Drone Project\\2020 CA alfalfa\predatorPMS.jpg', format='jpg', dpi=600)

# %% [markdown]
# ### For Rachel Magazine: natural enemy

# %%
# plot comparison data - natural enemy
harlan_ne=harlan[harlan['trtment']!= 'Control']
payne_ne=payne[payne['trtment']!= 'Control']
fig, axes = plt.subplots(nrows=1,ncols=2,figsize = (12, 6))
sns.set(font_scale = 1.2)
sns.set_style("white")
## plot armyworm 10 GPA
g1=sns.boxplot(x = harlan_ne['trtment'],y = harlan_ne['ne'],
               hue = harlan_ne['dat'],data = harlan_ne,ax=axes[0],
            order=['Drone','Airplane'],palette='Purples',
            showmeans=True,width=0.6,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})

# Add transparency to colors
for patch in g1.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor((r, g, b, .5))
# style   
g1.set_ylabel('Number of Predators per 10 Sweeps',fontsize=16,fontweight='bold')
g1.legend(loc=2,fontsize = 12) 
g1.set_xlabel('')
labels=['UAV','Airplane']
g1.set_xticklabels(labels,fontsize=16,fontweight='bold')
g1.set_title('Field Site #1 ( 10 GPA)',fontweight='bold')
g1.set_ylim(0,30)

# add mean at 0DAY
horiz_line_data = df.iloc[48:52]['ne'].mean()
g1.axhline(y=horiz_line_data,color='gray',linewidth=3, linestyle=':',label='0 DAY')
#g1.hlines(y=horiz_line_data, xmin=xlim[0], xmax=xlim[1], colors='gray', linestyles=':', label='0 DAY')
g1.legend(loc=1,fontsize = 12) 

######################################################################    
## plot armyworm 5 GPA
g2=sns.boxplot(x = payne_ne['trtment'],y = payne_ne['ne'],
               hue = payne_ne['dat'],data = payne_ne,ax=axes[1],
            order=['Drone','Airplane'],palette='BuGn',showmeans=True,width=0.6,
              meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
# Add transparency to colors
for patch in g2.artists:
 r,g,b, a = patch.get_facecolor()
 patch.set_facecolor(( r, g, b,.5))
# add mean at 0DAY
horiz_line_data = df.iloc[52:57]['ne'].mean()
g2.axhline(y=horiz_line_data,color='gray',linewidth=3, linestyle=':',label='0 DAY')
g2.legend(loc=1,fontsize = 12) 
# style   
g2.set_ylabel('Number of Predators per 10 Sweeps',fontsize=16,fontweight='bold')
g2.legend(loc=0,fontsize = 12) 
g2.set_xlabel('')
labels=['UAV','Airplane']
g2.set_ylim(0,30)
g2.set_xticklabels(labels,fontsize=16,fontweight='bold')
g2.set_title('Field Site #2 (5 GPA)',fontweight='bold')

# # Add a table at the bottom of the axes
# the_table = plt.table(cellText=cell_text,
#                       rowLabels=rows,
#                       rowColours=colors,
#                       colLabels=columns,
#                       loc='bottom')
# st=fig.suptitle("Natural enemy population by application methods over time ",fontsize=18,fontweight='bold')
# st.set_y(1.05)
fig.tight_layout()
fig.savefig('D:\\3. WorkSpace\\Drone Project\\2020 CA alfalfa\predatorMAZ.jpg', format='jpg', dpi=600)

# %% [markdown]
# ## 2. Alfalfa data - pooled comparison

# %%
# Querying -Analytical -test1 
# Loading Excel
alf1 = pd.read_excel(r'D:\3. WorkSpace\Drone Project\2020 CA alfalfa\2. Data\5. biological and python data\data-drone_aircraft_2020.xlsx',
                     #encoding='latin1',
                     sheet_name = 'AlfalfaTest1')
alf1 = alf1.set_index(['exp_unit'])
alf1.head()
# Out:
#          trtment quadrant  rep  mass (ug)  conc (ug/g leaf)
# exp_unit
# 1          DRONE       Q1    1  51.599776          5.606112
# 2          DRONE       Q1    2  57.200249          4.936162
# 3          DRONE       Q1    3  87.082485          6.433209
# 4          DRONE       Q1    4  86.206675          7.077898
# 5          DRONE       Q1    5  71.625165          4.820030

# %%
# Querying -Analytical -test2 
# Loading Excel
alf2 = pd.read_excel(r'D:\3. WorkSpace\Drone Project\2020 CA alfalfa\2. Data\5. biological and python data\data-drone_aircraft_2020.xlsx',
                     #encoding='latin1',
                     sheet_name = 'AlfalfaTest2')
alf2 = alf2.set_index(['exp_unit'])
alf2.head()
# Out:
#          trtment quadrant  rep   mass (ug)  conc (ug/g leaf)
# exp_unit
# 1          DRONE       Q1    1  288.062799         15.207543
# 2          DRONE       Q1    2   84.349741          6.519232
# 3          DRONE       Q1    3   63.138435          4.040808
# 4          DRONE       Q1    4  116.387012          6.769363
# 5          DRONE       Q1    5   68.540237          4.320298

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize = (12, 6))
sns.set(font_scale = 1.2)
sns.set_style("whitegrid")
## plot armyworm 10 GPA
g1=sns.violinplot(x = alf1['trtment'],y = alf1['conc (ug/g leaf)'],data = alf1,ax=axes[0],
            order=['DRONE','MANNED'],palette='Set2',
            showmeans=True,linewidth=2.5,width=.6,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
# Add in points to show each observation
sns.stripplot(x=alf1['trtment'], y=alf1['conc (ug/g leaf)'], data=alf1,ax=axes[0],
              size=8, color= 'purple', alpha =0.5, linewidth=0,)

# Add transparency to colors
for patch in g1.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor((r, g, b, .05))
# style   
g1.set_ylabel('Chlorantraniliprole concentration\n on alfalfa samples (ug ai/g plant tissue)',
              fontsize=16,fontweight='bold')
#g1.legend(loc=2,fontsize = 12) 
g1.set_xlabel('')
g1.set_ylim(-5,30)
#g1.grid(axis='y')
labels=['UAV\n(PV35)','Airplane\n(AT-502)']
g1.set_xticklabels(labels,fontsize=14,fontweight='bold')
g1.set_title('Field Site A (93.5 L/ha or 10 GPA)',fontweight='bold')
######################################################################    
## plot armyworm 5 GPA
g2=sns.violinplot(x = alf2['trtment'],y = alf2['conc (ug/g leaf)'],data = alf2,ax=axes[1],
            order=['DRONE','MANNED'],palette="Set2",
            showmeans=True,linewidth=2.5,width=.6,
              meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
# Add in points to show each observation
sns.stripplot(x=alf2['trtment'], y=alf2['conc (ug/g leaf)'], data=alf1,ax=axes[1],
              size=8, color= 'purple', alpha =0.5, linewidth=0,)
# Add transparency to colors
for patch in g2.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor(( r, g, b,.05))

# style   
g2.set_ylabel('Chlorantraniliprole concentration\n on alfalfa samples (ug ai/g plant tissue)', #'Chlorantraniliprole concentration\n on alfalfa samples (ug ai/g leaf)',
              fontsize=16,fontweight='bold')
#g2.legend(loc=0,fontsize = 12) 
g2.set_xlabel('')
g2.set_ylim(-5,30)
#g2.grid(axis='y')
labels=['UAV\n(PV35)','Airplane\n(AG-CAT D)']
g2.set_xticklabels(labels,fontsize=14,fontweight='bold')
g2.set_title('Field Site B (46.8 L/ha or 5 GPA)',fontweight='bold') 
# # Add a table at the bottom of the axes
# the_table = plt.table(cellText=cell_text,
#                       rowLabels=rows,
#                       rowColours=colors,
#                       colLabels=columns,
#                       loc='bottom')
# st=fig.suptitle("Overall deposition recovery between application methods",fontsize=18,fontweight='bold')
# st.set_y(1.05)
fig.tight_layout()
fig.savefig('D:\\3. WorkSpace\\Drone Project\\2020 CA alfalfa\sum residuesPMS.jpg', 
            format='jpg', dpi=600)

# %% [markdown]
# ### For Rachel Magazine: overall residues

# %%
fig, axes = plt.subplots(nrows=1,ncols=2,figsize = (12, 6))
sns.set(font_scale = 1.2)
sns.set_style("whitegrid")
## plot armyworm 10 GPA
g1=sns.boxplot(x = alf1['trtment'],y = alf1['conc (ug/g leaf)'],data = alf1,ax=axes[0],
            order=['DRONE','MANNED'],palette='Set2',
            showmeans=True,linewidth=2.5,width=.6,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
# Add in points to show each observation
sns.stripplot(x=alf1['trtment'], y=alf1['conc (ug/g leaf)'], data=alf1,ax=axes[0],
              size=8, color= 'purple', alpha =0.5, linewidth=0,)

# style   
g1.set_ylabel('Chlorantraniliprole insecticide concentration',
              fontsize=16,fontweight='bold')
#g1.legend(loc=2,fontsize = 12) 
g1.set_xlabel('')
g1.set_ylim(-5,30)
#g1.grid(axis='y')
labels=['UAV\n(PV35)','Airplane\n(AT-502)']
g1.set_xticklabels(labels,fontsize=14,fontweight='bold')
g1.set_title('Field Site #1 (10 GPA)',fontweight='bold')
######################################################################    
## plot armyworm 5 GPA
g2=sns.boxplot(x = alf2['trtment'],y = alf2['conc (ug/g leaf)'],data = alf2,ax=axes[1],
            order=['DRONE','MANNED'],palette="Set2",
            showmeans=True,linewidth=2.5,width=.6,
              meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
# Add in points to show each observation
sns.stripplot(x=alf2['trtment'], y=alf2['conc (ug/g leaf)'], data=alf1,ax=axes[1],
              size=8, color= 'purple', alpha =0.5, linewidth=0,)

# style   
g2.set_ylabel('Chlorantraniliprole insecticide concentration', #'Chlorantraniliprole concentration\n on alfalfa samples (ug ai/g leaf)',
              fontsize=16,fontweight='bold')
#g2.legend(loc=0,fontsize = 12) 
g2.set_xlabel('')
g2.set_ylim(-5,30)
#g2.grid(axis='y')
labels=['UAV\n(PV35)','Airplane\n(AG-CAT D)']
g2.set_xticklabels(labels,fontsize=14,fontweight='bold')
g2.set_title('Field Site #2 (5 GPA)',fontweight='bold') 
# # Add a table at the bottom of the axes
# the_table = plt.table(cellText=cell_text,
#                       rowLabels=rows,
#                       rowColours=colors,
#                       colLabels=columns,
#                       loc='bottom')
# st=fig.suptitle("Overall deposition recovery between application methods",fontsize=18,fontweight='bold')
# st.set_y(1.05)
fig.tight_layout()
fig.savefig('D:\\3. WorkSpace\\Drone Project\\2020 CA alfalfa\sum residues.jpg', 
            format='jpg', dpi=600)

# %%
fig, axes = plt.subplots(nrows=1,ncols=1,figsize = (10, 5))
sns.set(font_scale = 1.2)
sns.set_style("whitegrid")
## plot armyworm 10 GPA
g1=sns.boxplot(x = alf2['quandrant'],y = alf2['conc (ug / g leaf)'],hue ='trtment',data = alf2,
            order=['Q1','Q2','Q3','Q4'],palette='Set1',
            showmeans=True,linewidth=2.5,width=.6,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
# # Add in points to show each observation
# sns.stripplot(x=alf2['quandrant'], y=alf2['conc (ug / g leaf)'],hue ='trtment', data=alf2,
#               size=8, color= 'purple', alpha =0.5, linewidth=0,)

# Add transparency to colors
for patch in g1.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor((r, g, b, .45))
# style   
g1.set_ylabel('Concentrations (ug / g leaf)',fontsize=16)
#g1.legend(loc=2,fontsize = 12) 
g1.set_xlabel('')
#g1.set_ylim(0,35)

# labels=['Unmaned','Manned']
# g1.set_xticklabels(labels,fontsize=16)
g1.set_title('Variations within the four quandrants at Payne Location (46.8 L/ha or 5 GPA)',fontsize =16)
# Out:
# Text(0.5, 1.0, 'Variations within the four quandrants at Payne Location (46.8 L/ha or 5 GPA)')

# %% [markdown]
# ## 3. Spray Card+Filter Paper+Alfalfa

# %%
# Querying -Analytical -2 
# Loading Excel
alf2 = pd.read_excel(r'D:\3. WorkSpace\Drone Project\2020 CA alfalfa\2. Data\5. biological and python data\data-drone_aircraft_2020.xlsx',
                  sheet_name = 'AlfalfaTest2')
alf2 = alf2.set_index(['exp_unit'])

# %%
# Querying -Filter
# Loading Excel
flt2 = pd.read_excel(r'D:\3. WorkSpace\Drone Project\2020 CA alfalfa\2. Data\5. biological and python data\data-drone_aircraft_2020.xlsx',
                  sheet_name = 'FilterTest2')
flt2 = flt2.set_index(['exp_unit'])

# %%
# Querying - Card
# Loading Excel
crd2 = pd.read_excel(r'D:\3. WorkSpace\Drone Project\2020 CA alfalfa\2. Data\5. biological and python data\data-drone_aircraft_2020.xlsx',
                  sheet_name = 'CardTest2')
crd2 = crd2.set_index(['exp_unit'])

# %%
grp = ['crd2','flt2','alf2']
df2 = pd.concat([crd2,flt2, alf2], axis = 1, keys = grp)
df2.columns.names = ['Test Set','Measurement Info']
df2.head(3)
# Out:
# Test Set            crd2                                              \
# Measurement Info trtment quadrant rep ID spray coverage drop density
# exp_unit
# 1                  DRONE       Q1   1 -2         16.681       46.760
# 2                  DRONE       Q1   2 -1          9.366       38.398
# 3                  DRONE       Q1   3  0          4.040       16.333
#
# Test Set                                                     ...     flt2      \
# Measurement Info volume density     DV10     Dv50      Dv90  ... quadrant rep
# exp_unit                                                     ...
# 1                        13.024  329.280  730.329  1145.305  ...       Q1   1
# 2                         6.066  258.942  603.061   981.910  ...       Q1   2
# 3                         3.189  283.235  774.613  1333.207  ...       Q1   3
#
# Test Set                                                                     \
# ...

# %%
# Loading Excel
all = pd.read_excel(r'D:\3. WorkSpace\Drone Project\2020 CA alfalfa\2. Data\5. biological and python data\data-drone_aircraft_2020.xlsx',
                  sheet_name = 'Test2')
all = all.set_index(['exp_unit'])

# %%
def corrfunc(x,y, ax=None, **kws):
    """Plot the correlation coefficient in the top left hand corner of a plot."""
    coef = np.corrcoef(x, y)[0][1]
    label = r'$\rho$ = ' + str(round(coef, 2))
    # Add the label to the plot
    ax = plt.gca()
    ax.annotate(label, xy = (0.2, 0.95), size = 20, xycoords = ax.transAxes)
    
#     ax = ax or plt.gca()
#     # Unicode for lowercase rho (ρ)
#     rho = '\u03C1'
#     ax.annotate(f'{rho} = {r:.2f}', xy=(.1, .9), xycoords=ax.transAxes)
    
g=sns.pairplot(all,hue='trtment', palette='Set2')
g.map_lower(corrfunc)

# %%
uav=df2[df2['crd2']['trtment'] == 'DRONE']
air=df2[df2['crd2']['trtment'] == 'MANNED']

# %%
x = uav['crd2']['quadrant']
y = uav['crd2']['VMD']
sns.boxplot(x = uav['crd2']['quadrant'],y = uav['crd2']['VMD'],data = uav['crd2'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'VMD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-bc170a38eb17> in <module>
#       1 x = uav['crd2']['quadrant']
# ...

# %% [markdown]
# # 4. three tier comparision

# %%
# Loading Excel
all = pd.read_excel(r'D:\3. WorkSpace\Drone Project\2020 CA alfalfa\2. Data\5. biological and python data\data-drone_aircraft_2020.xlsx',
                    #encoding='latin1',
                    sheet_name = 'Test2')
all = all.set_index(['exp_unit'])
all
# Out:
#          trtment quadrant  coverage%  drop/cm  gal/ac      VMD  conc (ug/cm2)  \
# exp_unit
# 1          DRONE       Q1     16.681   46.760  13.024  730.329       0.937256
# 2          DRONE       Q1      9.366   38.398   6.066  603.061       0.357265
# 3          DRONE       Q1      4.040   16.333   3.189  774.613       0.159803
# 4          DRONE       Q1     12.493   38.241   9.835  726.536       0.451393
# 5          DRONE       Q1      3.731   14.301   2.159  477.744       0.166917
# 6          DRONE       Q2     18.713   51.761  14.582  723.899       0.345127
# 7          DRONE       Q2      8.503   37.720   5.127  552.740       0.308568
# 8          DRONE       Q2      3.603   14.249   2.859  796.902       0.122987
# 9          DRONE       Q2     11.222   35.428   8.439  698.877       0.335447
# 10         DRONE       Q2      3.410   13.259   1.949  480.055       0.328113
# 11         DRONE       Q3     10.763   35.298   7.668  685.824       0.336730
# ...

# %%
# Set up the matplotlib figure
fig, (ax1, ax2, ax3)  = plt.subplots(nrows=3,ncols=1,figsize = (10, 12))
sns.set_context(context = 'paper', font_scale = 1.2)
sns.set_style("whitegrid")

## plot coverage%
# Add in points to show each observation
p=sns.stripplot(x = all['trtment'], y = all['coverage%'], data = all,ax=ax1,
              hue = 'quadrant',jitter=0.15, dodge=True, 
              size=8, palette='Set1', alpha =0.5, linewidth=0)

g1=sns.boxplot(x = all['trtment'],y = all['coverage%'],data = all,ax=ax1,
            hue = 'quadrant',palette='Set1',
            showmeans=True,linewidth=2.5,width=.6,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"10"})
# Add transparency to colors
for patch in g1.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor((r, g, b, .55))

# style   
g1.set_ylabel('Spray coverage (%)',fontsize=14,fontweight='bold')
g1.set_ylim(0,25)
g1.set_xlabel('')
g1.set_xticks([])
# g1.set_title('Variations within the four quandrants at Payne Location (46.8 L/ha or 5 GPA)',
#              fontsize =16,fontweight='bold')
g1.legend_.remove() 

##########################################################################
## plot Flt
g2=sns.boxplot(x = all['trtment'],y = all['conc (ug/cm2)'],data = all,ax=ax2,
            hue = 'quadrant',palette='Set1',
            showmeans=True,linewidth=2.5,width=.6,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"10"})

# Add transparency to colors
for patch in g2.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor((r, g, b, .55))
# Add in points to show each observation
sns.stripplot(x = all['trtment'], y = all['conc (ug/cm2)'], data = all,ax=ax2,
              hue = 'quadrant',jitter=0.15, dodge=True,
              size=8, palette='Set1', alpha =0.5, linewidth=0)
# style   
g2.set_ylabel('Chlorantraniliprole concentration\n on filter paper (ug ai/$\mathregular{cm^{2}}$)',
              fontsize=14,fontweight='bold')

g2.set_yticks(np.arange(0, 1.64, step=0.4))  # Set label locations.
#g2.set_ylim(0,1.64)
g2.set_xlabel('')
g2.set_xticks([])
g2.legend_.remove() 
# ##########################################################################
## plot Alf
g3=sns.boxplot(x = all['trtment'],y = all['conc (ug/g leaf)'],data = all,ax=ax3,
              hue = 'quadrant',palette='Set1',
            showmeans=True,linewidth=2.5,width=.6,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"10"})
# Add transparency to colors
for patch in g3.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor((r, g, b, .55))
# Add in points to show each observation
sns.stripplot(x = all['trtment'], y = all['conc (ug/g leaf)'], data = all,ax=ax3,
              hue = 'quadrant',jitter=0.15, dodge=True,
              size=8, palette='Set1', alpha =0.5, linewidth=0)
# style   
g3.set_ylabel('Chlorantraniliprole concentration\n on alfalfa (ug ai/g plant tissue)',
              fontsize=14, fontweight='bold')
g3.set_ylim(0,25)
g3.set_xlabel('')
labels=['UAV\n(PV35)','Airplane\n(AG-CAT D)']
g3.set_xticklabels(labels,fontsize=14,fontweight='bold')

handles, labels = p.get_legend_handles_labels()
plt.legend(handles[4:],labels[4:],
           loc="upper right",
           fontsize = 12,
           markerscale = 1,
           frameon=True,
           labelspacing=0.2).set_title('Quadrant')
fig.tight_layout
fig.savefig('D:\\3. WorkSpace\\Drone Project\\2020 CA alfalfa\\tierPMS.jpg',
            format='jpg', dpi=600)

# %%
uav = all.loc[all['trtment']=='DRONE']
uav.head()
# Out:
#          trtment quadrant  Spray coverage (%)  drop/cm  gal/ac      VMD  \
# exp_unit
# 1          DRONE       Q1              16.681   46.760  13.024  730.329
# 2          DRONE       Q1               9.366   38.398   6.066  603.061
# 3          DRONE       Q1               4.040   16.333   3.189  774.613
# 4          DRONE       Q1              12.493   38.241   9.835  726.536
# 5          DRONE       Q1               3.731   14.301   2.159  477.744
#
#           Chlorantraniliprole concentration\n on filter paper (ug ai/$\mathregular{cm^{2}}$)  \
# exp_unit
# 1                                                  2.854256
# 2                                                  1.087990
# 3                                                  0.486653
# 4                                                  1.374643
# 5                                                  0.508317
#
#           Chlorantraniliprole concentration\n on alfalfa samples (ug ai/g leaf)  \
# exp_unit
# ...

# %%
uav = all.loc[all['trtment']=='DRONE']
air = all.loc[all['trtment']=='MANNED']

# Set up the matplotlib figure
fig, (ax1, ax2, ax3)  = plt.subplots(nrows=3,ncols=1,figsize = (5, 12))
sns.set_context(context = 'paper', font_scale = 1.2)
sns.set_style("whitegrid")

## plot coverage%

g=sns.distplot(uav['coverage%'], kde_kws={"color":"red"}, hist=False, ax=ax1,label='Unmanned',
             rug=False)
sns.distplot(air['coverage%'], kde_kws={"color":"blue"}, hist=False, ax=ax1, 
             rug=False,label='Manned')
# Get the two lines from the axes to generate shading
l11 = ax1.lines[0]
l12 = ax1.lines[1]

# Get the xy data from the lines so that we can shade
x1 = l11.get_xydata()[:,0]
y1 = l11.get_xydata()[:,1]
x2 = l12.get_xydata()[:,0]
y2 = l12.get_xydata()[:,1]
ax1.fill_between(x1,y1, color="red", alpha=0.2)
ax1.fill_between(x2,y2, color="blue", alpha=0.2)

# style   
ax1.set_xlim(-10,30)
ax1.set_ylim(0,0.14)
ax1.set_xlabel('Spray coverage (%)',fontsize=14,fontweight='bold')
ax1.set_ylabel('Probability density',fontsize=14,fontweight='bold')
g.legend()

############################################################################
sns.distplot(uav['conc (ug/cm2)'], kde_kws={"color":"red"}, hist=False, ax=ax2,
             rug=False)
sns.distplot(air['conc (ug/cm2)'], kde_kws={"color":"blue"}, hist=False, ax=ax2,
             rug=False)
# Get the two lines from the axes to generate shading
l21 = ax2.lines[0]
l22 = ax2.lines[1]

# Get the xy data from the lines so that we can shade
x1 = l21.get_xydata()[:,0]
y1 = l21.get_xydata()[:,1]
x2 = l22.get_xydata()[:,0]
y2 = l22.get_xydata()[:,1]
ax2.fill_between(x1,y1, color="red", alpha=0.2)
ax2.fill_between(x2,y2, color="blue", alpha=0.2)

# style   
ax2.set_xlim(-0.8,2.4)
ax2.set_ylim(0,3.5)
ax2.set_xlabel('Chlorantraniliprole concentration\n on filter paper (ug ai/$\mathregular{cm^{2}}$)',
               fontsize=14,fontweight='bold')
ax2.set_ylabel('Probability density',fontsize=14,fontweight='bold')
# g2.legend_.remove() 

# # ##########################################################################
# ## plot Alf
sns.distplot(uav['conc (ug/g leaf)'], kde_kws={"color":"red"}, hist=False, ax=ax3,
             rug=False)
sns.distplot(air['conc (ug/g leaf)'], kde_kws={"color":"blue"}, hist=False, ax=ax3,
             rug=False)
# Get the two lines from the axes to generate shading
l31 = ax3.lines[0]
l32 = ax3.lines[1]

# Get the xy data from the lines so that we can shade
x1 = l31.get_xydata()[:,0]
y1 = l31.get_xydata()[:,1]
x2 = l32.get_xydata()[:,0]
y2 = l32.get_xydata()[:,1]
ax3.fill_between(x1,y1, color="red", alpha=0.2)
ax3.fill_between(x2,y2, color="blue", alpha=0.2)

# style   
ax3.set_xlim(-10,30)
ax3.set_ylim(0,0.20)
ax3.set_xlabel('Chlorantraniliprole concentration\n on alfalfa samples (ug ai/g leaf)',
               fontsize=14,fontweight='bold')
ax3.set_ylabel('Probability density',fontsize=14,fontweight='bold')
#plt.gcf().subplots_adjust(bottom=0.10)
fig.tight_layout()
fig.savefig('D:\\3. WorkSpace\\Drone Project\\2020 CA alfalfa\\kdePMS.jpg',
            format='jpg', dpi=600)
# Out:
# C:\Users\X\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\X\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
all[all['trtment']== 'DRONE']['coverage%']
# Out:
# exp_unit
# 1     16.681
# 2      9.366
# 3      4.040
# 4     12.493
# 5      3.731
# 6     18.713
# 7      8.503
# 8      3.603
# 9     11.222
# 10     3.410
# 11    10.763
# 12    11.238
# 13     4.261
# 14    12.437
# 15    19.274
# 16    13.927
# 17    13.342
# 18     2.004
# 19     6.676
# 20    10.553
# Name: coverage%, dtype: float64

# %%
#fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2,figsize = (10, 4))
sns.set_context(context = 'paper', font_scale = 1.1)
sns.set_style("whitegrid")

uav=pd.DataFrame({'spray coverage\n (%)':all[all['trtment']== 'DRONE']['coverage%'],
                 'filter paper recovery\n (ug/cm2)':all[all['trtment']== 'DRONE']['conc (ug/cm2)'],
                 'alfalfa residue\n (ug/g plant)':all[all['trtment']== 'DRONE']['conc (ug/g leaf)'],})
uav_corr = uav.corr()

air=pd.DataFrame({'spray coverage\n (%)':all[all['trtment']== 'MANNED']['coverage%'],
                 'filter paper recovery\n (ug/cm2)':all[all['trtment']== 'MANNED']['conc (ug/cm2)'],
                 'alfalfa residue\n (ug/g plant)':all[all['trtment']== 'MANNED']['conc (ug/g leaf)'],})
#                 'PC1':all[all['trtment']== 'MANNED']['PC1'],
#                 'PC2':all[all['trtment']== 'MANNED']['PC2']})
air_corr = air.corr()

# matrix1 = np.triu(uav_corr)
ax1=sns.clustermap(uav_corr, annot = True,cmap="vlag", cbar_kws={"shrink": .8},
                   col_cluster=False, row_cluster=True, vmin=0.6, vmax=1.0,figsize=(6, 6),square=True)
ax1.fig.suptitle('UAV (PV35) application',fontweight='bold') 

# matrix2 = np.triu(air_corr)
ax2=sns.clustermap(air_corr, annot = True,cmap="vlag",
                   col_cluster=False, row_cluster=True, vmin=0.6, vmax=1.0,figsize=(6, 6))
ax2.fig.suptitle('Airplane (AG-CAT D) application',fontweight='bold')
# print(ax1.collections[0]) square=True,
#fig.colorbar(ax1.collections[0], cax=ax1[2])
# Out:
# Text(0.5, 0.98, 'Airplane (AG-CAT D) application')

# %%
fig, (ax1, ax2)  = plt.subplots(nrows=1,ncols=2,figsize = (14, 6))
sns.set_context(context = 'paper', font_scale = 1.2)
sns.set_style("whitegrid")

uav=pd.DataFrame({'spray coverage ':all[all['trtment']== 'DRONE']['coverage%'],
                 'filter paper recovery':all[all['trtment']== 'DRONE']['conc (ug/cm2)'],
                 'alfalfa residue':all[all['trtment']== 'DRONE']['conc (ug/g leaf)'],})
uav_corr = uav.corr()

air=pd.DataFrame({'spray coverage':all[all['trtment']== 'MANNED']['coverage%'],
                 'filter paper recovery':all[all['trtment']== 'MANNED']['conc (ug/cm2)'],
                 'alfalfa residue':all[all['trtment']== 'MANNED']['conc (ug/g leaf)'],})
#                   'PC1':all[all['trtment']== 'MANNED']['PC1'],
#                  'PC2':all[all['trtment']== 'MANNED']['PC2']})
air_corr = air.corr()
# matrix1 = np.triu(uav_corr)
sns.heatmap(uav_corr, annot = True,cmap="vlag", ax=ax1,fmt='.2g',vmin=0.6, vmax=1.0,cbar=False,
           linewidths=1.0, linecolor='white',square = True, cbar_kws={"shrink": .8})
ax1.set_title('UAV (PV35) application',fontweight='bold')

# matrix2 = np.triu(air_corr)
sns.heatmap(air_corr, annot = True,cmap="vlag", ax=ax2,fmt='.2g',vmin=0.6, vmax=1.0,cbar=True,
           linewidths=1.0, linecolor='white',square = True, cbar_kws={"shrink": .8})
ax2.set_title('Airplane (AG-CAT D) application',fontweight='bold')
fig.tight_layout()
#fig.savefig('D:\\3. WorkSpace\\Drone Project\\2020 CA alfalfa\\heatmapPMS.jpg',
#            format='jpg', dpi=600)

# %%
# all = all.rename(columns = {'coverage%':'Spray coverage (%)',
#                             'conc (ug/cm2)':'Chlorantraniliprole concentration\n on filter paper (ug ai/$\mathregular{cm^{2}}$)',
#                             'conc (ug/g leaf)':'Chlorantraniliprole concentration\n on alfalfa samples (ug ai/g leaf)'})

grid = sns.pairplot(all[['trtment','Spray coverage (%)',
                         'Chlorantraniliprole concentration\n on filter paper (ug ai/$\mathregular{cm^{2}}$)',
                         'Chlorantraniliprole concentration\n on alfalfa samples (ug ai/g leaf)']],hue='trtment', 
               diag_kind="kde",markers=["o", "s"],
               height=4,
               palette='Set1')

# for ax in grid.axes.flat:
#     _ = plt.setp(ax.get_yticklabels(), visible=True)
#     _ = plt.setp(ax.get_xticklabels(), visible=True)
    
# xlabels =['Spray coverage (%)',
#          'Chlorantraniliprole concentration\n on filter paper (ug ai/$\mathregular{cm^{2}}$)',
#          'Chlorantraniliprole concentration\n on alfalfa samples (ug ai/g leaf)']
# ylabels =['Spray coverage (%)',
#          'Chlorantraniliprole concentration\n on filter paper (ug ai/$\mathregular{cm^{2}}$)',
#          'Chlorantraniliprole concentration\n on alfalfa samples (ug ai/g leaf)']

# for i in range(len(xlabels)):
#     for j in range(len(ylabels)):
#         grid.axes[j,i].xaxis.set_label_text(xlabels[i])
#         grid.axes[j,i].yaxis.set_label_text(ylabels[j])

        
# handles, labels = plt.gca().get_legend_handles_labels()
# plt.legend(handles,label=['Unmanned','Manned'],
#            loc="upper right",
#            fontsize = 12,
#            markerscale = 1.5,
#            frameon=True,
#            labelspacing=0.2)

# %%
df=pd.DataFrame({'coverage':air['crd2']['coverage%'],
                 'drop density':air['crd2']['drop/cm'],
                 'drop size':air['crd2']['VMD'],
                 'filter':air['flt2']['conc (ug/cm2)'],
                 'alfalfa':air['alf2']['conc (ug/g leaf)']})
air_corr = df.corr()
sns.clustermap(air_corr, annot = True,cmap="vlag",figsize = (10, 4))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crd2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-4b8aaa19e793> in <module>
# ...

# %% [markdown]
# # 5. Spray Cards

# %%
# Loading Excel
cards = pd.read_excel(r'D:\3. WorkSpace\Drone Project\2020 CA alfalfa\2. Data\python data\data-drone_aircraft_2020.xlsx',
                    encoding='latin1',
                    sheet_name = 'PCA')
cards.head()
# Out:
#    spray coverage  drop density  volume density     DV10     Dv50      Dv90  \
# 0          16.681        46.760          13.024  329.280  730.329  1145.305
# 1           9.366        38.398           6.066  258.942  603.061   981.910
# 2           4.040        16.333           3.189  283.235  774.613  1333.207
# 3          12.493        38.241           9.835  343.162  726.536  1175.475
# 4           3.731        14.301           2.159  242.164  477.744  1058.848
#
#     Span trtment       PC1       PC2       PC3 trtment.1
# 0  1.117   DRONE -2.472250  2.399820 -1.044530     DRONE
# 1  1.199   DRONE  0.866796  2.224440  0.315181     DRONE
# 2  1.355   DRONE  1.878610 -0.732295 -1.937120     DRONE
# 3  1.146   DRONE -1.371560  1.445460 -1.040580     DRONE
# 4  1.709   DRONE  4.353400  0.877974 -0.644956     DRONE

# %%
cards.loc[cards['trtment']=='DRONE'].describe()
# Out:
#        spray coverage  drop density  volume density        DV10        Dv50  \
# count       20.000000     20.000000       20.000000   20.000000   20.000000
# mean         9.811850     30.589600        7.103250  292.513250  647.549600
# std          5.222649     12.164339        4.169991   44.719321  109.960229
# min          2.004000     10.055000        1.419000  201.522000  394.815000
# 25%          4.205750     19.456750        3.106500  251.453750  592.316500
# 50%         10.658000     34.321000        7.216500  298.125000  677.785500
# 75%         12.705250     38.567250        9.580750  329.281500  724.558250
# max         19.274000     51.761000       14.582000  366.652000  800.197000
#
#               Dv90       Span        PC1        PC2        PC3
# count    20.000000  20.000000  20.000000  20.000000  20.000000
# mean   1070.933350   1.217650   0.476915   1.539029  -0.306338
# std     145.178161   0.199094   2.278371   1.235449   0.981946
# ...

# %%
cards.loc[cards['trtment']=='MANNED'].describe()
# Out:
#        spray coverage  drop density  volume density        DV10        Dv50  \
# count       20.000000     20.000000       20.000000   20.000000   20.000000
# mean         8.019300     25.165150        6.440750  331.348050  752.767400
# std          2.492233      7.248571        2.238061   41.463856   84.106757
# min          4.101000     13.025000        2.809000  247.218000  590.304000
# 25%          6.277250     19.804750        4.954750  305.046250  690.513000
# 50%          7.689000     23.315000        5.818000  333.291000  774.283500
# 75%         10.395250     30.263250        8.261750  353.666750  813.532750
# max         12.936000     40.951000       10.170000  405.991000  881.975000
#
#               Dv90      Span        PC1        PC2        PC3
# count    20.000000  20.00000  20.000000  20.000000  20.000000
# mean   1200.507500   1.16865  -0.476916  -1.539030   0.306339
# std     105.532743   0.19129   1.292681   0.613385   0.881338
# ...

# %%
fig = plt.figure() 
# pass axes to fig
ax=fig.add_axes([0,0,1,1])
ax = sns.barplot(x = harlan['trtment'],y = harlan['ne'],hue = harlan['dat'],data = harlan,
            order=['Control','Drone','Airplane'],palette="tab10")
            #estimator=np.std,capsize=.1)
#ax.set_ylabel('Counts (number of armyworm/10 sweep)')
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)

change_width(ax, 0.375)

def show_values_on_bars(axs):
    def _show_on_single_plot(ax):        
        for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height()
            value = '{:.2f}'.format(p.get_height())
            ax.text(_x, _y, value, ha="center") 

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)
        
show_values_on_bars(ax)
